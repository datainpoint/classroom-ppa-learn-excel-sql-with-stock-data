# %% [markdown]
# # 數據分析的基石：使用活頁簿與資料庫玩轉結構化資料
#
# > 衍生計算欄位：運算符
#
# [郭耀仁](https://linktr.ee/yaojenkuo) | <yaojenkuo@datainpoint.com>

# %% [markdown]
# ## 練習題指引
#
# - 開始寫作之前，可以先按上方「Copy to Drive」按鈕將筆記本複製到自己的 Google 雲端硬碟。
# - 練習題共分為三種：是非題、單選題以及程式題。
# - 是非題：預設答案為 `None`，若覺得敘述**不正確**，就將 `None` 改寫為 `False`，覺得敘述**正確**，就將 `None` 改寫為 `True`
# - 單選題：覺得第一個選項**正確**，就將 `None` 改寫為 `1`，覺得第二個選項**正確**，就將 `None` 改寫為 `2`，覺得第三個選項**正確**，就將 `None` 改寫 `3`，覺得第四個選項**正確**，就將 `None` 改寫 `4`
# - 程式題：
#     - 在 SQL 語法起點與 SQL 語法終點這兩列註解之間撰寫能夠得到預期結果的 SQL
#     - 我們已經將學習資料庫載入環境，SQL 可以直接指定學習資料庫中的資料表，不需要額外指定資料庫。
#     - 可以先在自己電腦的 Letos 或者 DB Browser for SQLite 寫出跟預期結果相同的 SQL 後再複製貼上到練習題。
# - 執行測試的方式為點選右上角 Connect，然後點選上方選單的 Runtime -> Restart session and run all -> Yes -> Run anyway。
# - 移動到 Google Colab 的最後一個儲存格看測試結果。

# %%
# !wget -qN https://github.com/datainpoint/classroom-ppa-learn-excel-sql-with-stock-data/raw/refs/heads/main/datasets/twse.db

# %%
import sqlite3
import unittest
import pandas as pd
conn = sqlite3.connect('twse.db')

# %% [markdown]
# ## 0301（單選題）在活頁簿中使用 `TYPE()` 函數判斷資料型別時，下列關於輸出的解讀何者有誤？
#
# 1. 輸出為 1 代表數值（number）。
# 2. 輸出為 2 代表文字（text）。
# 3. 輸出為 4 代表邏輯值、布林值（logical）。
# 4. 輸出為 8 代表錯誤值（error）。

# %%
answer_0301 = None

# %% [markdown]
# ## 0302（單選題）在 SQLite 進行數值計算 `SELECT 314/100;` 的結果為何？
#
# 1. `3.14`
# 2. `14`
# 3. `3`
# 4. `157/50`

# %%
answer_0302 = None

# %% [markdown]
# ## 0303（程式題）從 `twse` 資料庫的 `trading_volumes` 資料表衍生計算 `volume_in_text` 顯示前 10 列觀測值，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(10, 2) 的查詢結果。
#
# ```
# volume	volume_in_text
# 762271	762.271張
# 1017650	1017.65張
# 381336	381.336張
# 442556	442.556張
# 546333	546.333張
# 491742	491.742張
# 557320	557.32張
# 827188	827.188張
# 702221	702.221張
# 212082	212.082張
# ```

# %%
answer_0303 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 0304（程式題）從 `twse` 資料庫的 `trading_volumes` 資料表衍生計算 `runtime_text` 顯示前 10 列觀測值，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(10, 2) 的查詢結果。
#
# ```
# volume	volume_in_text
# 762271	762張271股
# 1017650	1017張650股
# 381336	381張336股
# 442556	442張556股
# 546333	546張333股
# 491742	491張742股
# 557320	557張320股
# 827188	827張188股
# 702221	702張221股
# 212082	212張82股
# ```

# %%
answer_0304 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 0305（程式題）從 `twse` 資料庫的 `market_caps_closes` 資料表衍生計算 `market_cap_in_billion`，將市值數以「十億」為單位，顯示前 10 列觀測值，參考下列預期的查詢結果。
#
# - 預期輸出：(10, 2) 的查詢結果。
#
# ```
# market_cap	market_cap_in_billion
# 1369417842688	13694B
# 1174043230208	11740B
# 3568143171584	35681B
# 230148816896	2301B
# 2223381676032	22233B
# 741750865920	7417B
# 691922468864	6919B
# 758099935232	7580B
# 6200825479168	62008B
# 304969285632	3049B
# ```

# %%
answer_0305 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 執行測試！
#
# 點選右上角 Connect，然後點選上方選單的 Runtime -> Restart session and run all -> Yes -> Run anyway

# %%
class TestChapter03(unittest.TestCase):
    def test_0301(self):
        self.assertEqual(answer_0301, 4)
    def test_0302(self):
        self.assertEqual(answer_0302, 3)
    def test_0303(self):
        df = pd.read_sql(answer_0303, conn)
        self.assertEqual(df.shape, (10, 2))
        self.assertIn("張", df.iloc[:, 1].values[0])
    def test_0304(self):
        df = pd.read_sql(answer_0304, conn)
        self.assertEqual(df.shape, (10, 2))
        self.assertIn("張", df.iloc[:, 1].values[0])
        self.assertIn("股", df.iloc[:, 1].values[0])
    def test_0305(self):
        df = pd.read_sql(answer_0305, conn)
        self.assertEqual(df.shape, (10, 2))
        self.assertIn("B", df.iloc[:, 1].values[0])

suite = unittest.TestLoader().loadTestsFromTestCase(TestChapter03)
runner = unittest.TextTestRunner(verbosity=2)
test_results = runner.run(suite)
number_of_failures = len(test_results.failures)
number_of_errors = len(test_results.errors)
number_of_test_runs = test_results.testsRun
number_of_successes = number_of_test_runs - (number_of_failures + number_of_errors)
chapter_index = 3
chapter_name = "衍生計算欄位：運算符"

# %%
print(f"您在第 {chapter_index:02} 章「{chapter_name}」的 {number_of_test_runs} 道練習中答對了 {number_of_successes} 題。")
