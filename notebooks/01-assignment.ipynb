# %% [markdown]
# # 數據分析的基石：使用活頁簿與資料庫玩轉結構化資料
#
# > 簡介
#
# [郭耀仁](https://linktr.ee/yaojenkuo) | <yaojenkuo@datainpoint.com>

# %%
import unittest

# %% [markdown]
# ## 練習題指引
#
# - 開始寫作之前，可以先按上方「Copy to Drive」按鈕將筆記本複製到自己的 Google 雲端硬碟。
# - 練習題共分為三種：是非題、單選題以及程式題。
# - 是非題：預設答案為 `None`，若覺得敘述**不正確**，就將 `None` 改寫為 `False`，覺得敘述**正確**，就將 `None` 改寫為 `True`
# - 單選題：覺得第一個選項**正確**，就將 `None` 改寫為 `1`，覺得第二個選項**正確**，就將 `None` 改寫為 `2`，覺得第三個選項**正確**，就將 `None` 改寫 `3`，覺得第四個選項**正確**，就將 `None` 改寫 `4`
# - 程式題：
#     - 在 SQL 語法起點與 SQL 語法終點這兩列註解之間撰寫能夠得到預期結果的 SQL。
#     - 我們已經將兩個學習資料庫載入環境，SQL 可以直接指定兩個學習資料庫中的資料表，不需要額外指定資料庫。
#     - 可以先在自己電腦的 Letos 或者 DB Browser for SQLite 寫出跟預期結果相同的 SQL 後再複製貼上到練習題。
# - 執行測試的方式為點選右上角 Connect，然後點選上方選單的 Runtime -> Restart and run all -> Yes -> Run anyway。
# - 移動到 Google Colab 的最後一個儲存格看測試結果。

# %% [markdown]
# ## 0101（是非題）僅有資料探勘（Data Mining）可以稱得上是數據分析。

# %%
answer_0101 = None

# %% [markdown]
# ## 0102（是非題）這堂課程所使用的結構化資料僅有活頁簿。

# %%
answer_0102 = None

# %% [markdown]
# ## 0103（單選題）要順利與儲存於資料庫中的結構化資料進行互動，需要下列哪些工具共同運作？
#
# 1. 資料庫。
# 2. SQL（Structured Query Language）。
# 3. 資料庫管理系統。
# 4. 以上皆是。

# %%
answer_0103 = None

# %% [markdown]
# ## 0104（單選題）下列何者是這堂課程使用的活頁簿軟體？
#
# 1. Microsoft Excel
# 2. Apple Numbers
# 3. LibreOffice Calc
# 4. Google Sheets

# %%
answer_0104 = None

# %% [markdown]
# ## 0105（單選題）下列何者是這堂課程使用的資料庫管理系統？
#
# 1. MySQL
# 2. SQLite
# 3. PostgreSQL
# 4. SQL Server

# %%
answer_0105 = None

# %% [markdown]
# ## 執行測試！
#
# 點選右上角 Connect，然後點選上方選單的 Runtime -> Restart and run all -> Yes -> Run anyway。

# %%
class TestChapter01(unittest.TestCase):
    def test_0101(self):
        self.assertFalse(answer_0101)
    def test_0102(self):
        self.assertFalse(answer_0102)
    def test_0103(self):
        self.assertEqual(answer_0103, 4)
    def test_0104(self):
        self.assertEqual(answer_0104, 4)
    def test_0105(self):
        self.assertEqual(answer_0105, 2)

suite = unittest.TestLoader().loadTestsFromTestCase(TestChapter01)
runner = unittest.TextTestRunner(verbosity=2)
test_results = runner.run(suite)
number_of_failures = len(test_results.failures)
number_of_errors = len(test_results.errors)
number_of_test_runs = test_results.testsRun
number_of_successes = number_of_test_runs - (number_of_failures + number_of_errors)
chapter_index = 1
chapter_name = "簡介"

# %%
print(f"您在第 {chapter_index:02} 章「{chapter_name}」的 {number_of_test_runs} 道練習中答對了 {number_of_successes} 題。")
