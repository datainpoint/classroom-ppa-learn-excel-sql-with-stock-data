# %% [markdown]
# # 數據分析的基石：使用活頁簿與資料庫玩轉結構化資料
#
# > 子查詢與通用資料表運算式
#
# [郭耀仁](https://linktr.ee/yaojenkuo) | <yaojenkuo@datainpoint.com>

# %% [markdown]
# ## 練習題指引
#
# - 開始寫作之前，可以先按上方「Copy to Drive」按鈕將筆記本複製到自己的 Google 雲端硬碟。
# - 練習題共分為三種：是非題、單選題以及程式題。
# - 是非題：預設答案為 `None`，若覺得敘述**不正確**，就將 `None` 改寫為 `False`，覺得敘述**正確**，就將 `None` 改寫為 `True`
# - 單選題：覺得第一個選項**正確**，就將 `None` 改寫為 `1`，覺得第二個選項**正確**，就將 `None` 改寫為 `2`，覺得第三個選項**正確**，就將 `None` 改寫 `3`，覺得第四個選項**正確**，就將 `None` 改寫 `4`
# - 程式題：
#     - 在 SQL 語法起點與 SQL 語法終點這兩列註解之間撰寫能夠得到預期結果的 SQL
#     - 我們已經將學習資料庫載入環境，SQL 可以直接指定學習資料庫中的資料表，不需要額外指定資料庫。
#     - 可以先在自己電腦的 Letos 或者 DB Browser for SQLite 寫出跟預期結果相同的 SQL 後再複製貼上到練習題。
# - 執行測試的方式為點選右上角 Connect，然後點選上方選單的 Runtime -> Restart session and run all -> Yes -> Run anyway。
# - 移動到 Google Colab 的最後一個儲存格看測試結果。

# %%
# !wget -qN https://github.com/datainpoint/classroom-ppa-learn-excel-sql-with-stock-data/raw/refs/heads/main/datasets/twse.db

# %%
import sqlite3
import unittest
import pandas as pd
conn = sqlite3.connect('twse.db')

# %% [markdown]
# ## 0901（是非題）資料庫的使用者可以任意新增資料表、檢視表，就如同在活頁簿中新增工作表一般自由。

# %%
answer_0901 = None

# %% [markdown]
# ## 0902（是非題）初學子查詢可先寫出分段查詢，再以「後向推導」的方式寫出子查詢。

# %%
answer_0902 = None

# %% [markdown]
# ## 0903（單選題）通用資料表運算式的英文全名為何？
#
# 1. Common Table Examination, CTE.
# 2. Calculated Table Execution, CTE.
# 3. Common Table Expression, CTE.
# 4. Cumulative Table Expression, CTE。

# %%
answer_0903 = None

# %% [markdown]
# ## 0904（單選題）下列敘述何者有誤？
#
# 1. 使用 `WITH` 敘述可以建立通用資料表運算式。
# 2. 通用資料表運算式可以不必在同一個 SQL 敘述中進行定義與使用。
# 3. 我們可以將通用資料表運算式視為一種暫存的資料表。
# 4. 子查詢可以將先執行的內層查詢作為像變數一般的存在，供後執行的外層查詢使用。

# %%
answer_0904 = None

# %% [markdown]
# ## 0905（程式題）從 `twse` 資料庫的 `tickers` 資料表以子查詢的技巧找出最早與最晚上市上櫃的個股，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(m, 3) 的查詢結果。
#
# ```
# ticker	stock	listed_on
# 2308.TW	台達電	1988-12-19
# 6983.TWO	華洋精機	2026-05-25
# ```

# %%
answer_0905 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 0906（程式題）從 `twse` 資料庫以子查詢的技巧找出收盤價排名最低的十個標的，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(10, 2) 的查詢結果。
#
# ```
# ticker	stock
# 1268.TWO	漢來美食
# 2752.TWO	豆府
# 3611.TWO	鼎翰
# 5475.TWO	德宏
# 5483.TWO	中美晶
# 5903.TWO	全家
# 6761.TWO	穩得
# 6907.TWO	雅特力-KY
# 6922.TWO	宸曜
# 7703.TWO	銳澤
# ```

# %%
answer_0906 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 0907（程式題）從 `twse` 資料庫以子查詢的技巧找出市值排名最低的十支個股（排除市值為 `NULL` 的 ETF），參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(10, 2) 的查詢結果。
#
# ```
# ticker	stock
# 2752.TWO	豆府
# 6538.TWO	倉和
# 6761.TWO	穩得
# 6870.TWO	騰雲
# 6922.TWO	宸曜
# 6953.TWO	家碩
# 6983.TWO	華洋精機
# 7556.TWO	意德士
# 7703.TWO	銳澤
# 7810.TWO	捷創科技
# ```

# %%
answer_0907 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 0908（程式題）從 `twse` 資料庫以通用資料表運算式的技巧找出資料期間內，自由現金流量（`free_cashflow`）總和大於零的個股（排除自由現金流量為 `NULL` 的 ETF），參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(m, 2) 的查詢結果。
#
# ```
# ticker	stock
# 1264.TWO	德麥
# 1268.TWO	漢來美食
# 1476.TW	儒鴻
# 1519.TW	華城
# 1560.TW	中砂
# 1590.TW	亞德客-KY
# 2049.TW	上銀
# 2059.TW	川湖
# 2207.TW	和泰車
# 2308.TW	台達電
# ...(skip)
# ```

# %%
answer_0908 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 執行測試！
#
# 點選右上角 Connect，然後點選上方選單的 Runtime -> Restart session and run all -> Yes -> Run anyway。

# %%
class TestChapter09(unittest.TestCase):
    def test_0901(self):
        self.assertFalse(answer_0901)
    def test_0902(self):
        self.assertTrue(answer_0902)
    def test_0903(self):
        self.assertEqual(answer_0903, 3)
    def test_0904(self):
        self.assertEqual(answer_0904, 2)
    def test_0905(self):
        df = pd.read_sql(answer_0905, conn)
        m, n = df.shape
        self.assertEqual(n, 3)
        self.assertLess(m, 5)
        self.assertLess(str(df.iloc[:, 2][0]), "2000-01-01")
        self.assertGreater(str(df.iloc[:, 2][1]), "2020-01-01")
    def test_0906(self):
        df = pd.read_sql(answer_0906, conn)
        m, n = df.shape
        self.assertEqual(m, 10)
        self.assertEqual(n, 2)
    def test_0907(self):
        df = pd.read_sql(answer_0907, conn)
        m, n = df.shape
        self.assertEqual(m, 10)
        self.assertEqual(n, 2)
    def test_0908(self):
        df = pd.read_sql(answer_0908, conn)
        m, n = df.shape
        self.assertLess(m, 200)
        self.assertEqual(n, 2)
suite = unittest.TestLoader().loadTestsFromTestCase(TestChapter09)
runner = unittest.TextTestRunner(verbosity=2)
test_results = runner.run(suite)
number_of_failures = len(test_results.failures)
number_of_errors = len(test_results.errors)
number_of_test_runs = test_results.testsRun
number_of_successes = number_of_test_runs - (number_of_failures + number_of_errors)
chapter_index = 9
chapter_name = "子查詢與通用資料表運算式"

# %%
print(f"您在第 {chapter_index:02} 章「{chapter_name}」的 {number_of_test_runs} 道練習中答對了 {number_of_successes} 題。")
