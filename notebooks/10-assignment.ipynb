# %% [markdown]
# # 數據分析的基石：使用活頁簿與資料庫玩轉結構化資料
#
# > 關聯資料
#
# [郭耀仁](https://linktr.ee/yaojenkuo) | <yaojenkuo@datainpoint.com>

# %% [markdown]
# ## 練習題指引
#
# - 開始寫作之前，可以先按上方「Copy to Drive」按鈕將筆記本複製到自己的 Google 雲端硬碟。
# - 練習題共分為三種：是非題、單選題以及程式題。
# - 是非題：預設答案為 `None`，若覺得敘述**不正確**，就將 `None` 改寫為 `False`，覺得敘述**正確**，就將 `None` 改寫為 `True`
# - 單選題：覺得第一個選項**正確**，就將 `None` 改寫為 `1`，覺得第二個選項**正確**，就將 `None` 改寫為 `2`，覺得第三個選項**正確**，就將 `None` 改寫 `3`，覺得第四個選項**正確**，就將 `None` 改寫 `4`
# - 程式題：
#     - 在 SQL 語法起點與 SQL 語法終點這兩列註解之間撰寫能夠得到預期結果的 SQL
#     - 我們已經將學習資料庫載入環境，SQL 可以直接指定學習資料庫中的資料表，不需要額外指定資料庫。
#     - 可以先在自己電腦的 Letos 或者 DB Browser for SQLite 寫出跟預期結果相同的 SQL 後再複製貼上到練習題。
# - 執行測試的方式為點選右上角 Connect，然後點選上方選單的 Runtime -> Restart session and run all -> Yes -> Run anyway。
# - 移動到 Google Colab 的最後一個儲存格看測試結果。

# %%
# !wget -qN https://github.com/datainpoint/classroom-ppa-learn-excel-sql-with-stock-data/raw/refs/heads/main/datasets/twse.db

# %%
import sqlite3
import unittest
import pandas as pd
conn = sqlite3.connect('twse.db')

# %% [markdown]
# ## 1001（是非題）使用 `JOIN` 與 `FULL JOIN` 的時候，左資料表（在 `FROM` 之後）或右資料表（在 `JOIN` 之後）的指定沒有差別。

# %%
answer_1001 = None

# %% [markdown]
# ## 1002（是非題）使用 `LEFT JOIN` 與 `RIGHT JOIN` 的時候，左資料表（在 `FROM` 之後）或右資料表（在 `JOIN` 之後）的指定沒有差別。

# %%
answer_1002 = None

# %% [markdown]
# ## 1003（是非題）使用任何的連接類型時，`ON` 之後左資料表的連接鍵或右資料表的連接鍵在書寫順序上沒有差別。

# %%
answer_1003 = None

# %% [markdown]
# ## 1004（單選題）下列有關於 `UNION` 的敘述何者有誤？
#
# 1. `UNION` 前後敘述所選擇的欄位數要相同。
# 2. 若有使用到 `ORDER BY` 只能放在 `UNION` 之後。
# 3. `UNION ALL` 會省略重複觀測值。
# 4. 簡單來說，就是將觀測值垂直合併至同一個查詢結果。

# %%
answer_1004 = None

# %% [markdown]
# ## 1005（程式題）從 `twse` 資料庫運用關聯資料的技巧找出市值前十高的上市公司，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(10, 3) 的查詢結果。
#
# ```
# ticker	stock	market_cap
# 2330.TW	台積電	61719040753664
# 2454.TW	聯發科	6200825479168
# 2308.TW	台達電	4727529013248
# 6669.TW	緯穎	3568143171584
# 3711.TW	日月光投控	3119191162880
# 2383.TW	台光電	2223381676032
# 3037.TW	欣興	1823836471296
# 2408.TW	南亞科	1595793342464
# 2059.TW	川湖	1369417842688
# 2382.TW	廣達	1340542550016
# ```

# %%
answer_1005 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 1006（程式題）從 `twse` 資料庫運用關聯資料的技巧找出市值前十高的上櫃公司，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(10, 3) 的查詢結果。
#
# ```
# ticker	stock	market_cap
# 5274.TWO	信驊	709197234176
# 6223.TWO	旺矽	516361519104
# 6488.TWO	環球晶	506800537600
# 6274.TWO	台燿	446041489408
# 8299.TWO	群聯	442329989120
# 3081.TWO	聯亞	270613037056
# 3293.TWO	鈊象	209096769536
# 3529.TWO	力旺	174767587328
# 5289.TWO	宜鼎	140687966208
# 6187.TWO	萬潤	122679656448
# ```

# %%
answer_1006 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 1007（程式題）承前兩題，運用 CTE、關聯資料的技巧將市值排名前十的上市公司、上櫃公司垂直合併呈現，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(20, 3) 的查詢結果。
#
# ```
# ticker	stock	market_cap
# 2330.TW	台積電	61719040753664
# 2454.TW	聯發科	6200825479168
# 2308.TW	台達電	4727529013248
# 6669.TW	緯穎	3568143171584
# 3711.TW	日月光投控	3119191162880
# 2383.TW	台光電	2223381676032
# 3037.TW	欣興	1823836471296
# 2408.TW	南亞科	1595793342464
# 2059.TW	川湖	1369417842688
# 2382.TW	廣達	1340542550016
# 5274.TWO	信驊	709197234176
# 6223.TWO	旺矽	516361519104
# 6488.TWO	環球晶	506800537600
# 6274.TWO	台燿	446041489408
# 8299.TWO	群聯	442329989120
# 3081.TWO	聯亞	270613037056
# 3293.TWO	鈊象	209096769536
# 3529.TWO	力旺	174767587328
# 5289.TWO	宜鼎	140687966208
# 6187.TWO	萬潤	122679656448
# ```

# %%
answer_1007 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 1008（程式題）從 `twse` 資料庫運用關聯資料的技巧，計算每支個股在資料期間的平均交易量，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(200, 3) 的查詢結果。
#
# ```
# ticker	stock	avg_volume
# 0057.TW	富邦摩台	20337.619047619
# 00675L.TW	富邦臺灣加權正2	2256545.86363636
# 1264.TWO	德麥	18632.8636363636
# 1268.TWO	漢來美食	44940.7272727273
# 1476.TW	儒鴻	1744455.40909091
# 1519.TW	華城	1388436.36363636
# 1560.TW	中砂	1547669.45454545
# 1590.TW	亞德客-KY	1007742.22727273
# 2049.TW	上銀	5222675.54545455
# 2059.TW	川湖	586092.045454545
# ...(skip)
# ```

# %%
answer_1008 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 1009（程式題）承前題，計算兩百支個股平均交易量的平均值，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(1, 1) 的查詢結果。
#
# ```
# avg_avg_volume
# 4186750.38968615
# ```

# %%
answer_1009 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 1010（程式題）承前兩題，運用 CTE 的技巧篩選出大於平均交易量平均值的個股，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(m, 3) 的查詢結果。
#
# ```
# ticker	stock	avg_volume
# 2049.TW	上銀	5222675.54545455
# 2308.TW	台達電	13263206.6818182
# 2327.TW	國巨	52453162.6363636
# 2330.TW	台積電	28786461.1363636
# 2357.TW	華碩	4867662.31818182
# 2368.TW	金像電	9222554.68181818
# 2376.TW	技嘉	9530095.90909091
# 2382.TW	廣達	25204933.9545455
# 2395.TW	研華	4996878.09090909
# 2408.TW	南亞科	84347706.0909091
# ...(skip)
# ```

# %%
answer_1010 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 執行測試！
#
# 點選右上角 Connect，然後點選上方選單的 Runtime -> Restart session and run all -> Yes -> Run anyway。

# %%
class TestChapter10(unittest.TestCase):
    def test_1001(self):
        self.assertTrue(answer_1001)
    def test_1002(self):
        self.assertFalse(answer_1002)
    def test_1003(self):
        self.assertTrue(answer_1003)
    def test_1004(self):
        self.assertEqual(answer_1004, 3)
    def test_1005(self):
        df = pd.read_sql(answer_1005, conn)
        m, n = df.shape
        self.assertEqual(n, 3)
        self.assertEqual(m, 10)
        for i in range(m):
            self.assertEqual(".TW", df.iloc[:, 0][i][-3:])
    def test_1006(self):
        df = pd.read_sql(answer_1006, conn)
        m, n = df.shape
        self.assertEqual(m, 10)
        self.assertEqual(n, 3)
        for i in range(m):
            self.assertEqual(".TWO", df.iloc[:, 0][i][-4:])
    def test_1007(self):
        df = pd.read_sql(answer_1007, conn)
        m, n = df.shape
        self.assertEqual(m, 20)
        self.assertEqual(n, 3)
    def test_1008(self):
        df = pd.read_sql(answer_1008, conn)
        m, n = df.shape
        self.assertEqual(m, 200)
        self.assertEqual(n, 3)
    def test_1009(self):
        df = pd.read_sql(answer_1009, conn)
        m, n = df.shape
        self.assertEqual(m, 1)
        self.assertEqual(n, 1)
    def test_1010(self):
        df = pd.read_sql(answer_1010, conn)
        m, n = df.shape
        self.assertLess(m, 200)
        self.assertEqual(n, 3)
suite = unittest.TestLoader().loadTestsFromTestCase(TestChapter10)
runner = unittest.TextTestRunner(verbosity=2)
test_results = runner.run(suite)
number_of_failures = len(test_results.failures)
number_of_errors = len(test_results.errors)
number_of_test_runs = test_results.testsRun
number_of_successes = number_of_test_runs - (number_of_failures + number_of_errors)
chapter_index = 10
chapter_name = "關聯資料"

# %%
print(f"您在第 {chapter_index:02} 章「{chapter_name}」的 {number_of_test_runs} 道練習中答對了 {number_of_successes} 題。")
