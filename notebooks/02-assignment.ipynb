# %% [markdown]
# # 數據分析的基石：使用活頁簿與資料庫玩轉結構化資料
#
# > 從資料表選擇欄位
#
# [郭耀仁](https://linktr.ee/yaojenkuo) | <yaojenkuo@datainpoint.com>

# %% [markdown]
# ## 練習題指引
#
# - 開始寫作之前，可以先按上方「Copy to Drive」按鈕將筆記本複製到自己的 Google 雲端硬碟。
# - 練習題共分為三種：是非題、單選題以及程式題。
# - 是非題：預設答案為 `None`，若覺得敘述**不正確**，就將 `None` 改寫為 `False`，覺得敘述**正確**，就將 `None` 改寫為 `True`
# - 單選題：覺得第一個選項**正確**，就將 `None` 改寫為 `1`，覺得第二個選項**正確**，就將 `None` 改寫為 `2`，覺得第三個選項**正確**，就將 `None` 改寫 `3`，覺得第四個選項**正確**，就將 `None` 改寫 `4`
# - 程式題：
#     - 在 SQL 語法起點與 SQL 語法終點這兩列註解之間撰寫能夠得到預期結果的 SQL
#     - 我們已經將學習資料庫載入環境，SQL 可以直接指定學習資料庫中的資料表，不需要額外指定資料庫。
#     - 可以先在自己電腦的 Letos 或者 DB Browser for SQLite 寫出跟預期結果相同的 SQL 後再複製貼上到練習題。
# - 執行測試的方式為點選右上角 Connect，然後點選上方選單的 Runtime -> Restart session and run all -> Yes -> Run anyway。
# - 移動到 Google Colab 的最後一個儲存格看測試結果。

# %%
# !wget -qN https://github.com/datainpoint/classroom-ppa-learn-excel-sql-with-stock-data/raw/refs/heads/main/datasets/twse.db

# %%
import sqlite3
import unittest
import pandas as pd
conn = sqlite3.connect('twse.db')

# %% [markdown]
# ## 0201（是非題）在 SQL 中保留字的大小寫會影響執行結果的對錯。

# %%
answer_0201 = None

# %% [markdown]
# ## 0202（單選題）下列敘述何者有誤？
#
# 1. `DISTINCT` 可以省略顯示重複的資料內容。
# 2. SQL 保留字的寫作順序可以隨意調動，例如 `FROM` 可以先於 `SELECT`
# 3. `LIMIT 5 OFFSET 5` 會使得查詢結果顯示資料表的第 6 到第 10 列。
# 4. 儲存在活頁簿/資料庫中的工作表/資料表是有兩個維度的資料結構。

# %%
answer_0202 = None

# %% [markdown]
# ## 0203（程式題）從 `twse` 資料庫的 `tickers` 資料表選擇 `stock`、`listed_on` 兩個變數，並且顯示第 11 列至第 15 列的觀測值，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(5, 2) 的查詢結果。
#
# ```
# stock	listed_on
# 和泰車	1997-02-25
# 台達電	1988-12-19
# 國巨	1993-10-22
# 台積電	1994-09-05
# 智邦	1995-11-15
# ```

# %%
answer_0203 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 0204（程式題）從 `twse` 資料庫的 `tickers` 資料表選擇 `stock` 一個變數，並取別名為 `company_name`，並且顯示第 6 列至第 15 列的觀測值，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(10, 1) 的查詢結果。
#
# ```
# company_name
# 華城
# 中砂
# 亞德客-KY
# 上銀
# 川湖
# 和泰車
# 台達電
# 國巨
# 台積電
# 智邦
# ```

# %%
answer_0204 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 0205（程式題）從 `twse` 資料庫的 `y_financials` 資料表選擇「不重複」的 `quarter_end` 變數，並取別名為 `distinct_quarter_end`，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(m, 1) 的查詢結果。
#
# ```
# distinct_quarter_end
# 2025-03-31
# 2025-06-30
# 2025-09-30
# 2025-12-31
# 2026-03-31
# 2024-12-31
# 2026-06-30
# ```

# %%
answer_0205 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 執行測試！
#
# 點選右上角 Connect，然後點選上方選單的 Runtime -> Restart and run all -> Yes -> Run anyway。

# %%
class TestChapter02(unittest.TestCase):
    def test_0201(self):
        self.assertFalse(answer_0201)
    def test_0202(self):
        self.assertEqual(answer_0202, 2)
    def test_0203(self):
        df = pd.read_sql(answer_0203, conn)
        self.assertEqual(df.shape, (5, 2))
    def test_0204(self):
        df = pd.read_sql(answer_0204, conn)
        self.assertEqual(df.shape, (10, 1))
        self.assertEqual(df.columns[0], "company_name")
    def test_0205(self):
        df = pd.read_sql(answer_0205, conn)
        self.assertEqual(df.shape[1], 1)
        self.assertEqual(df.columns[0], "distinct_quarter_end")

suite = unittest.TestLoader().loadTestsFromTestCase(TestChapter02)
runner = unittest.TextTestRunner(verbosity=2)
test_results = runner.run(suite)
number_of_failures = len(test_results.failures)
number_of_errors = len(test_results.errors)
number_of_test_runs = test_results.testsRun
number_of_successes = number_of_test_runs - (number_of_failures + number_of_errors)
chapter_index = 2
chapter_name = "從資料表選擇欄位"

# %%
print(f"您在第 {chapter_index:02} 章「{chapter_name}」的 {number_of_test_runs} 道練習中答對了 {number_of_successes} 題。")
