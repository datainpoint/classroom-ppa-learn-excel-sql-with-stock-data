# %% [markdown]
# # 數據分析的基石：使用活頁簿與資料庫玩轉結構化資料
#
# > 分組聚合與結果篩選
#
# [郭耀仁](https://linktr.ee/yaojenkuo) | <yaojenkuo@datainpoint.com>

# %% [markdown]
# ## 練習題指引
#
# - 開始寫作之前，可以先按上方「Copy to Drive」按鈕將筆記本複製到自己的 Google 雲端硬碟。
# - 練習題共分為三種：是非題、單選題以及程式題。
# - 是非題：預設答案為 `None`，若覺得敘述**不正確**，就將 `None` 改寫為 `False`，覺得敘述**正確**，就將 `None` 改寫為 `True`
# - 單選題：覺得第一個選項**正確**，就將 `None` 改寫為 `1`，覺得第二個選項**正確**，就將 `None` 改寫為 `2`，覺得第三個選項**正確**，就將 `None` 改寫 `3`，覺得第四個選項**正確**，就將 `None` 改寫 `4`
# - 程式題：
#     - 在 SQL 語法起點與 SQL 語法終點這兩列註解之間撰寫能夠得到預期結果的 SQL
#     - 我們已經將學習資料庫載入環境，SQL 可以直接指定學習資料庫中的資料表，不需要額外指定資料庫。
#     - 可以先在自己電腦的 Letos 或者 DB Browser for SQLite 寫出跟預期結果相同的 SQL 後再複製貼上到練習題。
# - 執行測試的方式為點選右上角 Connect，然後點選上方選單的 Runtime -> Restart session and run all -> Yes -> Run anyway。
# - 移動到 Google Colab 的最後一個儲存格看測試結果。

# %%
# !wget -qN https://github.com/datainpoint/classroom-ppa-learn-excel-sql-with-stock-data/raw/refs/heads/main/datasets/twse.db

# %%
import sqlite3
import unittest
import pandas as pd
conn = sqlite3.connect('twse.db')

# %% [markdown]
# ## 0801（是非題）在資料庫中使用 `GROUP BY` 搭配聚合函數使用可以便捷地達成分組聚合應用。

# %%
answer_0801 = None

# %% [markdown]
# ## 0802（單選題）下列敘述何者有誤？
#
# 1. SQL 的 `WHERE` 作用在觀測值維度；`HAVING` 作用在分組聚合結果。
# 2. SQL 的 `WHERE` 與 `HAVING` 的差別為 `WHERE` 作用在分組聚合之前；`HAVING` 作用在分組聚合之後。
# 3. 在活頁簿中可以透過 Pivot table 完成分組聚合。
# 4. `GROUP BY` 不可以單獨使用，一定要搭配聚合函數使用。

# %%
answer_0802 = None

# %% [markdown]
# ## 0803（程式題）從 `twse` 資料庫的 `tickers` 資料表以 `ticker` 欄位分類為 ETF、上市公司以及上櫃公司，並計算這三類的個股數量，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(m, 2) 的查詢結果。
#
# ```
# stock_type	counts
# ETF	2
# 上市公司	98
# 上櫃公司	100
# ```

# %%
answer_0803 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 0804（程式題）承上題，將個股數量小於 10 個的類別剔除，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(m, 2) 的查詢結果。
#
# ```
# stock_type	counts
# 上市公司	98
# 上櫃公司	100
# ```

# %%
answer_0804 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 0805（程式題）從 `twse` 資料庫的 `market_caps_closes` 資料表將收盤價小於 300、收盤價小於 1000 與收盤價大於等於 1000 的個股分為三類，並計算這三類的個股數量，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# |收盤價切點|類別|
# |-------|---|
# |`< 300`|低價股|
# |`< 1000`|中價股|
# |`>= 1000`|高價股|
#
# - 預期輸出：(m, 2) 的查詢結果。
#
# ```
# close_range	counts
# 中價股	93
# 低價股	57
# 高價股	50
# ```

# %%
answer_0805 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 0806（程式題）承上題，計算三類個股的平均市值，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# |收盤價切點|類別|
# |-------|---|
# |`< 300`|低價股|
# |`< 1000`|中價股|
# |`>= 1000`|高價股|
#
# - 預期輸出：(m, 2) 的查詢結果。
#
# ```
# close_range	avg_market_cap
# 中價股	176558372683.956
# 低價股	25494226518.8571
# 高價股	1939321942630.4
# ```

# %%
answer_0806 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 0807（程式題）承上題，將平均市值低於 300 億台幣的類別剔除，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(m, 2) 的查詢結果。
#
# ```
# close_range	avg_market_cap
# 中價股	176558372683.956
# 高價股	1939321942630.4
# ```

# %%
answer_0807 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 執行測試！
#
# 點選右上角 Connect，然後點選上方選單的 Runtime -> Restart session and run all -> Yes -> Run anyway。

# %%
class TestChapter08(unittest.TestCase):
    def test_0801(self):
        self.assertTrue(answer_0801)
    def test_0802(self):
        self.assertEqual(answer_0802, 4)
    def test_0803(self):
        df = pd.read_sql(answer_0803, conn)
        m, n = df.shape
        self.assertEqual(n, 2)
        counts = df.iloc[:, 1]
        self.assertEqual(counts.sum(), 200)
    def test_0804(self):
        df = pd.read_sql(answer_0804, conn)
        m, n = df.shape
        self.assertEqual(n, 2)
        for i in range(m):
            self.assertLess(df.iloc[:, 1][i], 10)
    def test_0805(self):
        df = pd.read_sql(answer_0805, conn)
        m, n = df.shape
        self.assertEqual(n, 2)
        counts = df.iloc[:, 1]
        self.assertEqual(counts.sum(), 200)
    def test_0806(self):
        df = pd.read_sql(answer_0806, conn)
        m, n = df.shape
        self.assertEqual(n, 2)
        for i in range(m):
            self.assertIsInstance(df.iloc[:, 1][i], float)
    def test_0807(self):
        df = pd.read_sql(answer_0807, conn)
        m, n = df.shape
        self.assertEqual(n, 2)
        for i in range(m):
            self.assertGreater(df.iloc[:, 1][i], 30000000000)
suite = unittest.TestLoader().loadTestsFromTestCase(TestChapter08)
runner = unittest.TextTestRunner(verbosity=2)
test_results = runner.run(suite)
number_of_failures = len(test_results.failures)
number_of_errors = len(test_results.errors)
number_of_test_runs = test_results.testsRun
number_of_successes = number_of_test_runs - (number_of_failures + number_of_errors)
chapter_index = 8
chapter_name = "分組聚合與結果篩選"

# %%
print(f"您在第 {chapter_index:02} 章「{chapter_name}」的 {number_of_test_runs} 道練習中答對了 {number_of_successes} 題。")
