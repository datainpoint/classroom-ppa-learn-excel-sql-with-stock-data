# %% [markdown]
# # 數據分析的基石：使用活頁簿與資料庫玩轉結構化資料
#
# > 衍生計算欄位：條件邏輯
#
# [郭耀仁](https://linktr.ee/yaojenkuo) | <yaojenkuo@datainpoint.com>

# %% [markdown]
# ## 練習題指引
#
# - 開始寫作之前，可以先按上方「Copy to Drive」按鈕將筆記本複製到自己的 Google 雲端硬碟。
# - 練習題共分為三種：是非題、單選題以及程式題。
# - 是非題：預設答案為 `None`，若覺得敘述**不正確**，就將 `None` 改寫為 `False`，覺得敘述**正確**，就將 `None` 改寫為 `True`
# - 單選題：覺得第一個選項**正確**，就將 `None` 改寫為 `1`，覺得第二個選項**正確**，就將 `None` 改寫為 `2`，覺得第三個選項**正確**，就將 `None` 改寫 `3`，覺得第四個選項**正確**，就將 `None` 改寫 `4`
# - 程式題：
#     - 在 SQL 語法起點與 SQL 語法終點這兩列註解之間撰寫能夠得到預期結果的 SQL
#     - 我們已經將學習資料庫載入環境，SQL 可以直接指定學習資料庫中的資料表，不需要額外指定資料庫。
#     - 可以先在自己電腦的 Letos 或者 DB Browser for SQLite 寫出跟預期結果相同的 SQL 後再複製貼上到練習題。
# - 執行測試的方式為點選右上角 Connect，然後點選上方選單的 Runtime -> Restart session and run all -> Yes -> Run anyway。
# - 移動到 Google Colab 的最後一個儲存格看測試結果。

# %%
# !wget -qN https://github.com/datainpoint/classroom-ppa-learn-excel-sql-with-stock-data/raw/refs/heads/main/datasets/twse.db

# %%
import sqlite3
import unittest
import pandas as pd
conn = sqlite3.connect('twse.db')

# %% [markdown]
# ## 0701（是非題）應用條件邏輯時，當條件交集時會以寫作的順序決定判斷結果，優先寫作的條件會優先被採用。

# %%
answer_0701 = None

# %% [markdown]
# ## 0702（單選題）下列敘述何者正確？
#
# 1. 條件僅能夠被運用在篩選資料。
# 2. 條件邏輯就如同其他程式語言的 `if...else if...else...` 語法結構。
# 3. 在活頁簿中我們使用 `CASE WHEN` 語法結構實踐條件邏輯。
# 4. 在資料庫中我們使用 `CASE WHEN` 語法結構時一定要有 `ELSE` 敘述。

# %%
answer_0702 = None

# %% [markdown]
# ## 0703（程式題）從 `twse` 資料庫的 `market_caps_closes` 資料表將 `close` 分類為「小於等於一千」、「超過一千」兩個文字類別，取別名為 `close_range`，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(200, 2) 的查詢結果。
#
# ```
# close	close_range
# 14370	超過一千
# 6525	超過一千
# 6400	超過一千
# 6315	超過一千
# 6205	超過一千
# 5535	超過一千
# 5290	超過一千
# 5150	超過一千
# 3885	超過一千
# 3715	超過一千
# ...(skip)
# ```

# %%
answer_0703 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 0704（程式題）承上題，從 `twse` 資料庫的 `market_caps_closes` 資料表將 `close` 分類為「小於等於一千」、「超過一千」、「超過兩千」、「超過五千」四個文字類別，取別名為 `close_range`，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(200, 2) 的查詢結果。
#
# ```
# close	close_range
# 14370	超過五千
# 6525	超過五千
# 6400	超過五千
# 6315	超過五千
# 6205	超過五千
# 5535	超過五千
# 5290	超過五千
# 5150	超過五千
# 3885	超過兩千
# 3715	超過兩千
# ...(skip)
# ```

# %%
answer_0704 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 0705（程式題）從 `twse` 資料庫的 `tickers` 資料表將上市上櫃日期 `listed_on` 改以下列文字表示，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# |日期切點|年代|
# |-------|---|
# |`2000-01-01` 以前|三大法人成熟期|
# |`2020-01-01` 以前|商品多元化時期|
# |`2020-01-01` 迄今|全球半導體戰略期|
#
# - 預期輸出：(200, 2) 的查詢結果。
#
# ```
# listed_on	era_description
# 	無日期資料
# 	無日期資料
# 2015-04-09	商品多元化時期
# 2017-09-27	商品多元化時期
# 2001-04-18	商品多元化時期
# 1997-04-16	三大法人成熟期
# 2005-01-31	商品多元化時期
# 2010-12-13	商品多元化時期
# 2009-06-26	商品多元化時期
# 2008-06-25	商品多元化時期
# ```

# %%
answer_0705 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 執行測試！
#
# 點選右上角 Connect，然後點選上方選單的 Runtime -> Restart session and run all -> Yes -> Run anyway。

# %%
class TestChapter07(unittest.TestCase):
    def test_0701(self):
        self.assertTrue(answer_0701)
    def test_0702(self):
        self.assertEqual(answer_0702, 2)
    def test_0703(self):
        df = pd.read_sql(answer_0703, conn)
        m, n = df.shape
        self.assertEqual(m, 200)
        self.assertEqual(n, 2)
        unique_values = df.iloc[:, 1].unique()
        self.assertEqual(2, unique_values.size)
        self.assertIn("小於等於一千", unique_values)
        self.assertIn("超過一千", unique_values)
    def test_0704(self):
        df = pd.read_sql(answer_0704, conn)
        m, n = df.shape
        self.assertEqual(m, 200)
        self.assertEqual(n, 2)
    def test_0705(self):
        df = pd.read_sql(answer_0705, conn)
        m, n = df.shape
        self.assertEqual(m, 200)
        self.assertEqual(n, 2)
        unique_values = df.iloc[:, 1].unique()
        self.assertLessEqual(unique_values.size, 4)
        self.assertIn("商品多元化時期", unique_values)
        self.assertIn("三大法人成熟期", unique_values)
        self.assertIn("無日期資料", unique_values)
        self.assertIn("全球半導體戰略期", unique_values)
suite = unittest.TestLoader().loadTestsFromTestCase(TestChapter07)
runner = unittest.TextTestRunner(verbosity=2)
test_results = runner.run(suite)
number_of_failures = len(test_results.failures)
number_of_errors = len(test_results.errors)
number_of_test_runs = test_results.testsRun
number_of_successes = number_of_test_runs - (number_of_failures + number_of_errors)
chapter_index = 7
chapter_name = "條件邏輯"

# %%
print(f"您在第 {chapter_index:02} 章「{chapter_name}」的 {number_of_test_runs} 道練習中答對了 {number_of_successes} 題。")
