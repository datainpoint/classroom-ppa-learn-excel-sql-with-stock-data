# %% [markdown]
# # 數據分析的基石：使用活頁簿與資料庫玩轉結構化資料
#
# > 衍生計算欄位：函數
#
# [郭耀仁](https://linktr.ee/yaojenkuo) | <yaojenkuo@datainpoint.com>

# %% [markdown]
# ## 練習題指引
#
# - 開始寫作之前，可以先按上方「Copy to Drive」按鈕將筆記本複製到自己的 Google 雲端硬碟。
# - 練習題共分為三種：是非題、單選題以及程式題。
# - 是非題：預設答案為 `None`，若覺得敘述**不正確**，就將 `None` 改寫為 `False`，覺得敘述**正確**，就將 `None` 改寫為 `True`
# - 單選題：覺得第一個選項**正確**，就將 `None` 改寫為 `1`，覺得第二個選項**正確**，就將 `None` 改寫為 `2`，覺得第三個選項**正確**，就將 `None` 改寫 `3`，覺得第四個選項**正確**，就將 `None` 改寫 `4`
# - 程式題：
#     - 在 SQL 語法起點與 SQL 語法終點這兩列註解之間撰寫能夠得到預期結果的 SQL
#     - 我們已經將學習資料庫載入環境，SQL 可以直接指定學習資料庫中的資料表，不需要額外指定資料庫。
#     - 可以先在自己電腦的 Letos 或者 DB Browser for SQLite 寫出跟預期結果相同的 SQL 後再複製貼上到練習題。
# - 執行測試的方式為點選右上角 Connect，然後點選上方選單的 Runtime -> Restart session and run all -> Yes -> Run anyway。
# - 移動到 Google Colab 的最後一個儲存格看測試結果。

# %%
# !wget -qN https://github.com/datainpoint/classroom-ppa-learn-excel-sql-with-stock-data/raw/refs/heads/main/datasets/twse.db

# %%
import sqlite3
import unittest
import pandas as pd
conn = sqlite3.connect('twse.db')

# %% [markdown]
# ## 0401（是非題）在活頁簿或資料庫使用函數時一定要搭配引數（輸入或參數）才能運行。

# %%
answer_0401 = None

# %% [markdown]
# ## 0402（單選題）下列有關函數的敘述何者正確？
#
# 1. 聚合函數作用在「水平」方向，每個觀測值對應一個輸出。
# 2. 通用函數作用在「垂直」方向，整欄變數對應一個輸出。
# 3. 我們應該把所有的函數名稱與用法都記起來。
# 4. 以 SQLite 學習函數的知識也能擴展應用至其他不同的資料庫管理系統。

# %%
answer_0402 = None

# %% [markdown]
# ## 0403（程式題）從 `twse` 資料庫的 `tickers` 資料表計算距今最遠的 `listed_on` 與距今最近的 `listed_on`，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(1, 2) 的查詢結果。
#
# ```
# min_listed_on	max_listed_on
# 1988-12-19	2026-05-25
# ```

# %%
answer_0403 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 0404（程式題）承前題，從 `twse` 資料庫的 `tickers` 資料表計算距今最遠的 `listed_on` 與距今最近的 `listed_on` 並且改以「年份」呈現，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(1, 2) 的查詢結果。
#
# ```
# min_listed_on	max_listed_on
# 1988	2026
# ```

# %%
answer_0404 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 0405（程式題）從 `twse` 資料庫的 `trading_volumes` 資料表計算平均 `volume`、距今最遠的 `traded_on` 以及距今最近的 `traded_on`，平均 `volume` 請以 `ROUND()` 函數四捨五入到整數位，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(1, 3) 的查詢結果。
#
# ```
# avg_volume	min_traded_on	max_traded_on
# 4187698	2026-07-20	2026-08-18
# ```

# %%
answer_0405 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 0406（程式題）從 `twse` 資料庫的 `monthly_revenues` 資料表計算 `month_end` 變數的獨一值，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(6, 1) 的查詢結果。
#
# ```
# month_end
# 2025-05-31
# 2025-06-30
# 2025-07-31
# 2026-05-31
# 2026-06-30
# 2026-07-31
# ```

# %%
answer_0406 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 0407（程式題）承前題，從 `twse` 資料庫的 `monthly_revenues` 資料表 `month_end` 變數擷取「月份」並且取獨一值，參考下列預期的查詢結果（資料內容會隨金融數據的更新而不同，不影響批改測試）。
#
# - 預期輸出：(3, 1) 的查詢結果。
#
# ```
# distinct_months
# 05
# 06
# 07
# ```

# %%
answer_0407 =\
"""
-- SQL 語法起點

-- SQL 語法終點
"""

# %% [markdown]
# ## 執行測試！
#
# 點選右上角 Connect，然後點選上方選單的 Runtime -> Restart and run all -> Yes -> Run anyway。

# %%
class TestChapter04(unittest.TestCase):
    def test_0401(self):
        self.assertFalse(answer_0401)
    def test_0402(self):
        self.assertEqual(answer_0402, 4)
    def test_0403(self):
        df = pd.read_sql(answer_0403, conn)
        self.assertEqual(df.shape, (1, 2))
        self.assertEqual(10, len(df.iloc[:, 0].values[0]))
        self.assertEqual(10, len(df.iloc[:, 1].values[0]))
    def test_0404(self):
        df = pd.read_sql(answer_0404, conn)
        self.assertEqual(df.shape, (1, 2))
        self.assertEqual(4, len(df.iloc[:, 0].values[0]))
        self.assertEqual(4, len(df.iloc[:, 1].values[0]))
    def test_0405(self):
        df = pd.read_sql(answer_0405, conn)
        self.assertEqual(df.shape, (1, 3))
        self.assertEqual(10, len(df.iloc[:, 1].values[0]))
        self.assertEqual(10, len(df.iloc[:, 2].values[0]))
    def test_0406(self):
        df = pd.read_sql(answer_0406, conn)
        self.assertEqual(df.shape, (6, 1))
        for i in range(6):
            self.assertEqual(10, len(df.iloc[:, 0].values[i]))
    def test_0407(self):
        df = pd.read_sql(answer_0407, conn)
        self.assertEqual(df.shape, (3, 1))
        for i in range(3):
            self.assertEqual(2, len(df.iloc[:, 0].values[i]))

suite = unittest.TestLoader().loadTestsFromTestCase(TestChapter04)
runner = unittest.TextTestRunner(verbosity=2)
test_results = runner.run(suite)
number_of_failures = len(test_results.failures)
number_of_errors = len(test_results.errors)
number_of_test_runs = test_results.testsRun
number_of_successes = number_of_test_runs - (number_of_failures + number_of_errors)
chapter_index = 4
chapter_name = "衍生計算欄位：函數"

# %%
print(f"您在第 {chapter_index:02} 章「{chapter_name}」的 {number_of_test_runs} 道練習中答對了 {number_of_successes} 題。")
